# %% [markdown]
# # Fase 1: Análisis Exploratorio de Datos (EDA)
# **Objetivo:** Explorar el dataset de campanas publicitarias de Google Ads, limpiar los datos, realizar analisis exploratorio e ingenieria de caracteristicas para preparar el dataset para etapas de modelado posteriores.
#
# **Diccionario de Variables Clave:**
# * `Ad_ID`: Identificador unico de cada anuncio.
# * `Ad_Date`: Fecha en que se publico el anuncio.
# * `Campaign_Name`: Nombre de la campana publicitaria.
# * `Device`: Dispositivo desde el que se visualizo el anuncio.
# * `Location`: Ubicacion geografica del usuario.
# * `Clicks`: Numero de clics recibidos por el anuncio.
# * `Impressions`: Numero de veces que se mostro el anuncio.
# * `Leads`: Numero de clientes potenciales generados.
# * `Conversions`: Numero de conversiones completadas.
# * `Conversion Rate`: Porcentaje de clics que resultaron en conversion.
# * `Cost`: Costo de la campana publicitaria (en dolares).
# * `Sale_Amount`: Monto total de ventas generadas (en dolares).
# * `Is_Profitable`: Variable objetivo binaria definida por margen: `Profit_Margin = (Sale_Amount - Cost) / Cost`; `1` si `Profit_Margin >= tau`, `0` en caso contrario (con `tau` fijo o dinamico segun distribucion).

# %%
import os
os.makedirs('../results/plots', exist_ok=True)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Configuracion visual para que los graficos se vean profesionales
sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Cargamos el dataset y guardamos una copia cruda para comparar antes/despues
df = pd.read_csv('../data/raw/GoogleAds_DataAnalytics_Sales_Uncleaned.csv')
df_raw = df.copy()
print(f'Dimensiones del dataset: {df.shape}')
df.head()
# Out:
# Dimensiones del dataset: (2600, 13)
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       $1225  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       $1091  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# ...

# %% [markdown]
# ## 1. Inspeccion inicial y problemas de calidad
# Revisamos tipos de datos, valores nulos y posibles inconsistencias en el dataset crudo.

# %%
# Revisamos tipos de datos y valores nulos por columna
print(df.dtypes)
print()
print('Nulos por columna:')
print(df.isnull().sum())
# Out:
# Ad_ID               object
# Campaign_Name       object
# Clicks             float64
# Impressions        float64
# Cost                object
# Leads              float64
# Conversions        float64
# Conversion Rate    float64
# Sale_Amount         object
# Ad_Date             object
# Location            object
# Device              object
# Keyword             object
# dtype: object
#
# Nulos por columna:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions         74
# Conversion Rate    626
# Sale_Amount        139
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
# Contamos las filas duplicadas exactas
print(f'Filas duplicadas: {df.duplicated().sum()}')
print(f'Ad_ID duplicados: {df["Ad_ID"].duplicated().sum()}')
# Out:
# Filas duplicadas: 0
# Ad_ID duplicados: 0

# %%
# Estadisticas descriptivas de las columnas numericas originales
df.describe()
# Out:
#             Clicks  Impressions        Leads  Conversions  Conversion Rate
# count  2488.000000  2546.000000  2552.000000  2526.000000      1974.000000
# mean    138.956994  4523.280833    20.003918     6.519002         0.048979
# std      34.619376   869.927913     6.032317     2.272573         0.019987
# min      80.000000  3000.000000    10.000000     3.000000         0.015000
# 25%     110.000000  3764.000000    15.000000     5.000000         0.035000
# 50%     139.000000  4518.500000    20.000000     7.000000         0.046000
# 75%     169.000000  5279.500000    25.000000     9.000000         0.058000
# max     199.000000  5999.000000    30.000000    10.000000         0.123000

# %% [markdown]
# ## 2. Visualizacion inicial
# Antes de limpiar los datos, inspeccionamos la dispersion, los valores nulos y la relacion entre las variables numericas para detectar outliers y patrones fuertes en el dataset crudo.

# %%
# Variables numericas disponibles antes de la limpieza
raw_numeric_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate']

# Boxplot sobre datos crudos para detectar dispersion y outliers
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(data=df[raw_numeric_cols], orient='h', palette='Set3', ax=ax)
ax.set_title('Boxplot inicial de variables numericas', fontweight='bold')
ax.set_xlabel('Valor')
ax.set_ylabel('Variable')
plt.tight_layout()
plt.savefig('../results/plots/boxplot_inicial.png', dpi=150, bbox_inches='tight')
plt.show()

# Mapa de calor de valores nulos en el dataset crudo
fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(
    df.isnull(),
    cbar=False,
    yticklabels=False,
    cmap='YlOrRd',
    ax=ax,
)
ax.set_title('Mapa de calor de valores nulos (datos crudos)', fontweight='bold')
ax.set_xlabel('Columnas')
ax.set_ylabel('Registros')
plt.tight_layout()
plt.savefig('../results/plots/nulos_heatmap_inicial.png', dpi=150, bbox_inches='tight')
plt.show()

# Mapa de calor sobre datos crudos para ver correlaciones entre variables numericas
corr_raw = df[raw_numeric_cols].corr()
mask = np.triu(np.ones_like(corr_raw, dtype=bool))

fig, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(
    corr_raw,
    mask=mask,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    linewidths=0.5,
    square=True,
    ax=ax,
)
ax.set_title('Matriz de correlacion inicial', fontweight='bold')
plt.tight_layout()
plt.savefig('../results/plots/correlacion_inicial.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Limpieza de Datos

# %%
# Eliminamos filas duplicadas
df = df.drop_duplicates()

# Normalizamos Device a minusculas para unificar variantes
df['Device'] = df['Device'].str.strip().str.lower()

# Corregimos errores ortograficos en Location
df['Location'] = df['Location'].str.strip().str.lower()
df['Location'] = df['Location'].replace({'hyderbad': 'hyderabad', 'hydrebad': 'hyderabad'})

# Corregimos errores ortograficos en Campaign_Name
df['Campaign_Name'] = df['Campaign_Name'].str.strip()
df['Campaign_Name'] = df['Campaign_Name'].replace({
    'Data Anlytics Corse': 'Data Analytics Course',
    'Data Analytcis Course': 'Data Analytics Course',
    'Data Analytics Corse': 'Data Analytics Course',
    'DataAnalyticsCourse': 'Data Analytics Course',
})

# Eliminamos el simbolo $ y convertimos Cost y Sale_Amount a float
df['Cost'] = pd.to_numeric(
    df['Cost'].astype(str).str.replace(r'[\$,]', '', regex=True).str.strip(),
    errors='coerce'
)
df['Sale_Amount'] = pd.to_numeric(
    df['Sale_Amount'].astype(str).str.replace(r'[\$,]', '', regex=True).str.strip(),
    errors='coerce'
)

# Creamos Is_Profitable con margen sobre datos crudos monetarios
df['Profit_Margin'] = (df['Sale_Amount'] - df['Cost']) / df['Cost']
known_target_mask = df['Cost'].notna() & df['Sale_Amount'].notna()

tau_candidates = [0.1, 0.2, 0.3]
best_tau = None
best_score = None
best_target = None
selection_mode = 'fixed'

known_margin = df.loc[known_target_mask, 'Profit_Margin']
for tau in tau_candidates:
    y_tau = (known_margin >= tau).astype(int)
    pos_rate = y_tau.mean()
    score = abs(pos_rate - 0.5)
    if 0 < pos_rate < 1 and (best_score is None or score < best_score):
        best_score = score
        best_tau = tau
        best_target = y_tau

# Fallback dinamico si los taus fijos colapsan la clase
if best_target is None:
    finite_margin = known_margin.replace([np.inf, -np.inf], np.nan).dropna()
    best_tau = float(finite_margin.quantile(0.70))
    best_target = (known_margin >= best_tau).astype(int)
    selection_mode = 'dynamic_fallback'

df['Is_Profitable'] = pd.NA
df.loc[known_target_mask, 'Is_Profitable'] = best_target.values

# Excluimos targets desconocidos del set supervisado
unknown_count = (~known_target_mask).sum()
df = df.loc[known_target_mask].copy()
df['Is_Profitable'] = df['Is_Profitable'].astype(int)

print(f'Tau seleccionado: {best_tau:.4f} ({selection_mode})')
print(f'Registros supervisados: {len(df):,} | Excluidos por target desconocido: {unknown_count:,}')

# Parseamos Ad_Date con multiples formatos (ISO, DD-MM-YYYY, YYYY/MM/DD)
parsed = pd.to_datetime(df['Ad_Date'], format='mixed', dayfirst=False, errors='coerce')
mask_nat = parsed.isna()
parsed[mask_nat] = pd.to_datetime(df.loc[mask_nat, 'Ad_Date'], format='%d-%m-%Y', errors='coerce')
df['Ad_Date'] = parsed

# Eliminamos filas sin fecha (no imputables)
df = df.dropna(subset=['Ad_Date'])

# Imputamos columnas numericas con la mediana (robusta a outliers)
num_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Cost', 'Sale_Amount']
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# Recalculamos Conversion Rate donde era nulo usando Conversions / Clicks
mask_cr = df['Conversion Rate'].isna()
df.loc[mask_cr, 'Conversion Rate'] = (
    df.loc[mask_cr, 'Conversions'] / df.loc[mask_cr, 'Clicks']
)
df['Conversion Rate'] = df['Conversion Rate'].fillna(df['Conversion Rate'].median())

# Aplicamos Winsorizacion IQR para tratar outliers sin eliminar filas
outlier_cols = ['Clicks', 'Impressions', 'Cost', 'Sale_Amount', 'Leads', 'Conversions']
for col in outlier_cols:
    q1, q3 = df[col].quantile([0.25, 0.75])
    iqr = q3 - q1
    lo, hi = q1 - 1.5 * iqr, q3 + 1.5 * iqr
    df[col] = df[col].clip(lower=lo, upper=hi)

print(f'Shape final del dataset limpio: {df.shape}')
print('Nulos restantes:')
print(df.isnull().sum())
# Out:
# Tau seleccionado: 6.9320 (dynamic_fallback)
# Registros supervisados: 2,366 | Excluidos por target desconocido: 234
# Shape final del dataset limpio: (2366, 15)
# Nulos restantes:
# Ad_ID              0
# Campaign_Name      0
# Clicks             0
# Impressions        0
# Cost               0
# Leads              0
# Conversions        0
# Conversion Rate    0
# Sale_Amount        0
# Ad_Date            0
# Location           0
# Device             0
# Keyword            0
# Profit_Margin      0
# Is_Profitable      0
# dtype: int64

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# ### Comparaciones previas vs posteriores
# 1. Boxplot comparativo: primero mostramos la dispersión de las variables numéricas antes y después de la limpieza.
# 2. Correlación comparativa: después revisamos si cambian las relaciones principales entre variables numéricas.

# %%
# Estadisticas descriptivas tras la limpieza
df.describe()
# Out:
#             Clicks  Impressions         Cost        Leads  Conversions  \
# count  2366.000000  2366.000000  2366.000000  2366.000000  2366.000000
# mean    138.716399  4523.935334   214.933833    19.994928     6.536771
# min      80.000000  3000.000000   180.010000    10.000000     3.000000
# 25%     110.000000  3781.750000   197.285000    15.000000     5.000000
# 50%     139.000000  4524.000000   215.305000    20.000000     7.000000
# 75%     167.000000  5259.250000   232.695000    25.000000     8.000000
# max     199.000000  5999.000000   249.890000    30.000000    10.000000
# std      34.015012   857.377468    20.306830     5.995627     2.242988
#
#        Conversion Rate  Sale_Amount                        Ad_Date  \
# count      2366.000000  2366.000000                           2366
# mean          0.049716  1499.692730  2024-10-30 10:22:37.227387904
# min           0.015000  1000.000000            2024-01-11 00:00:00
# ...

# %%
# Definimos las variables numericas
num_feats = df.select_dtypes(include=[np.number]).columns.tolist()

# Calculamos y graficamos la matriz de correlacion entre variables numericas
affected_cols = [col for col in ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate', 'Cost', 'Sale_Amount', 'Profit_Margin', 'Is_Profitable'] if col in num_feats]
corr = df[affected_cols].corr()
fig, ax = plt.subplots(figsize=(10, 8))
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, annot=True, fmt='.2f',
            cmap='coolwarm', center=0, linewidths=0.5, ax=ax, square=True)
ax.set_title('Matriz de correlacion final', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('../results/plots/correlacion.png', bbox_inches='tight', dpi=150)
plt.show()

# Mostramos las correlaciones mas fuertes con Sale_Amount
print('Correlacion con Sale_Amount:')
print(corr['Sale_Amount'].sort_values(ascending=False).to_string())
# Out:
# Correlacion con Sale_Amount:
# Sale_Amount        1.000000
# Profit_Margin      0.890795
# Is_Profitable      0.693964
# Clicks             0.040551
# Cost               0.010845
# Leads              0.010610
# Conversions        0.003301
# Impressions       -0.004629
# Conversion Rate   -0.038060

# %%
# Comparación visual Antes / Después del Outlier Capping (IQR)
# Muestra el efecto del OutlierCapper en la distribución de cada variable numérica
numerical_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate']

# Calculamos los límites IQR y generamos el dataset sin outliers
df_sin_outliers = df.copy()
for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df_sin_outliers[col] = df[col].clip(lower, upper)

fig, axs = plt.subplots(len(numerical_cols), 2, figsize=(14, 5 * len(numerical_cols)))

for i, col in enumerate(numerical_cols):
    nombre = col.replace('_', ' ').title()

    # Columna izquierda — distribución ORIGINAL (rojo)
    sns.histplot(df[col].dropna(), bins=30, kde=True,
                 ax=axs[i, 0], color='indianred', stat='density')
    axs[i, 0].set_title(f'Distribución de {nombre}\n(Con Outliers Originales)',
                         fontweight='bold', fontsize=11)
    axs[i, 0].set_xlabel('')

    # Columna derecha — distribución DESPUÉS del capping (verde)
    sns.histplot(df_sin_outliers[col].dropna(), bins=30, kde=True,
                 ax=axs[i, 1], color='mediumseagreen', stat='density')
    axs[i, 1].set_title(f'Distribución de {nombre}\n(Atípicos Recortados)',
                         fontweight='bold', fontsize=11)
    axs[i, 1].set_xlabel('')

plt.suptitle('Efecto del Outlier Capping (IQR) por Variable Numérica',
             fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig('../results/plots/outlier_capping.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Comparacion de la matriz de correlacion antes y despues del procesamiento
raw_corr_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate']
processed_corr_cols = [col for col in ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate', 'Cost', 'Sale_Amount', 'Profit_Margin', 'Is_Profitable'] if col in df.columns]

corr_before = df_raw[raw_corr_cols].corr()
corr_after = df[processed_corr_cols].corr()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(
    corr_before,
    mask=np.triu(np.ones_like(corr_before, dtype=bool)),
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    linewidths=0.5,
    square=True,
    ax=axes[0],
)
axes[0].set_title('Correlacion inicial', fontweight='bold')

sns.heatmap(
    corr_after,
    mask=np.triu(np.ones_like(corr_after, dtype=bool)),
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    linewidths=0.5,
    square=True,
    ax=axes[1],
)
axes[1].set_title('Correlacion final', fontweight='bold')

plt.suptitle('Comparacion de correlaciones antes y despues de la limpieza', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('../results/plots/correlacion_comparativa.png', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# ## 5. Ingenieria de Caracteristicas

# %%
# Extraemos el dia de la semana a partir de la fecha
day_map = {0:'Lunes', 1:'Martes', 2:'Miercoles', 3:'Jueves',
           4:'Viernes', 5:'Sabado', 6:'Domingo'}
df['Day_of_Week'] = df['Ad_Date'].dt.dayofweek.map(day_map)
df['Month'] = df['Ad_Date'].dt.month

# Calculamos el ROAS (Return on Ad Spend): dinero generado por cada dolar invertido
df['ROAS'] = df['Sale_Amount'] / df['Cost'].replace(0, np.nan)

# Calculamos el CTR (Click-Through Rate): clics sobre impresiones
df['CTR'] = df['Clicks'] / df['Impressions'].replace(0, np.nan)

# Calculamos el CPC (Costo por Clic)
df['CPC'] = df['Cost'] / df['Clicks'].replace(0, np.nan)

# Is_Profitable ya fue creada en la etapa de limpieza con margen y tau
print(f'Campanas rentables segun margen/tau: '
      f'{df["Is_Profitable"].sum():,} de {len(df):,} ({df["Is_Profitable"].mean()*100:.1f}%)')
df[['Day_of_Week', 'ROAS', 'CTR', 'CPC', 'Is_Profitable']].describe()
# Out:
# Campanas rentables segun margen/tau: 710 de 2,366 (30.0%)
#               ROAS          CTR          CPC  Is_Profitable
# count  2366.000000  2366.000000  2366.000000    2366.000000
# mean      7.039524     0.031851     1.652740       0.300085
# std       1.510998     0.010234     0.464158       0.458391
# min       4.065534     0.013632     0.909394       0.000000
# 25%       5.826784     0.024147     1.286904       0.000000
# 50%       6.946268     0.030413     1.549634       0.000000
# 75%       8.153668     0.038117     1.944857       1.000000
# max      11.052632     0.065470     3.089500       1.000000

# %%
# Distribucion de la Variable Objetivo: Is_Profitable
# Logica actual: target por margen ((Sale_Amount - Cost) / Cost) con tau calibrado

plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df, x='Is_Profitable', palette='pastel')

# Agregamos el conteo encima de cada barra
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=11)

plt.title('Distribucion de la Variable Objetivo (Is_Profitable)', fontweight='bold')
plt.xlabel('Es Rentable (1 = Si, 0 = No)')
plt.ylabel('Cantidad de Campanas')
plt.xticks([0, 1], ['No Rentable (0)', 'Rentable (1)'])
plt.ylim(0, df['Is_Profitable'].value_counts().max() * 1.15)
plt.tight_layout()
plt.savefig('../results/plots/dist_objetivo.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'Rentable (1): {df["Is_Profitable"].mean()*100:.1f}%  |  No rentable (0): {(1-df["Is_Profitable"].mean())*100:.1f}%')
# Out:
# Rentable (1): 30.0%  |  No rentable (0): 70.0%

# %%
# Boxplot comparativo antes y despues de la limpieza
comparative_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate']

fig, axes = plt.subplots(1, 2, figsize=(16, 6), sharex=False)

sns.boxplot(data=df_raw[comparative_cols], orient='h', palette='Set3', ax=axes[0])
axes[0].set_title('Boxplot inicial (datos crudos)', fontweight='bold')
axes[0].set_xlabel('Valor')
axes[0].set_ylabel('Variable')

sns.boxplot(data=df[comparative_cols], orient='h', palette='Set2', ax=axes[1])
axes[1].set_title('Boxplot final (datos procesados)', fontweight='bold')
axes[1].set_xlabel('Valor')
axes[1].set_ylabel('Variable')

plt.suptitle('Comparacion de dispersion antes y despues de la limpieza', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('../results/plots/boxplot_comparativo.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Distribución de variables numéricas separadas por la variable objetivo
# Permite ver si el target discrimina bien cada feature
numerical_cols = ['Clicks', 'Impressions', 'Leads', 'Conversions', 'Conversion Rate']
target_col = 'Is_Profitable'

n_cols = 2
n_rows = -(-len(numerical_cols) // n_cols)  # ceil division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(numerical_cols):
    sns.histplot(
        data=df, x=col, hue=target_col, kde=True,
        ax=axes[i], bins=30, alpha=0.6, palette='Set2'
    )
    axes[i].set_title(f'Distribución de {col} por {target_col}', fontweight='bold')
    axes[i].set_ylabel('Densidad')

# Ocultamos el subplot sobrante si el número de variables es impar
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.savefig('../results/plots/dist_numericas_por_target.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Nota: el pipeline de data_preprocessing.py crea features adicionales de eficiencia
# que se calculan sobre los datos crudos ANTES de eliminar Cost y Sale_Amount.
# Estos features sí entran al modelo supervisado:
print("Features de eficiencia creadas en el pipeline (data_preprocessing.py):")
ratios_pipeline = {
    'cost_per_click':    'Cost / Clicks — costo promedio por clic',
    'cost_per_lead':     'Cost / Leads — costo promedio por lead',
    'revenue_per_click': 'Sale_Amount / Clicks — ingreso por clic',
    'revenue_per_lead':  'Sale_Amount / Leads — ingreso por lead',
    'ctr':               'Clicks / Impressions — click-through rate',
    'lead_rate':         'Leads / Clicks — tasa de conversión a lead',
}
for feat, desc in ratios_pipeline.items():
    print(f"  {feat:25s}: {desc}")
# Out:
# Features de eficiencia creadas en el pipeline (data_preprocessing.py):
#   cost_per_click           : Cost / Clicks — costo promedio por clic
#   cost_per_lead            : Cost / Leads — costo promedio por lead
#   revenue_per_click        : Sale_Amount / Clicks — ingreso por clic
#   revenue_per_lead         : Sale_Amount / Leads — ingreso por lead
#   ctr                      : Clicks / Impressions — click-through rate
#   lead_rate                : Leads / Clicks — tasa de conversión a lead

# %% [markdown]
# ## 6. Exportacion del Dataset Procesado
# Guardamos el dataset limpio y enriquecido listo para etapas de modelado posteriores.

# %%
# Exportamos el dataset limpio con las nuevas features
out_path = '../data/processed/GoogleAds_Processed.csv'
df.to_csv(out_path, index=False)

# Verificamos que el archivo tiene el mismo numero de filas
df_check = pd.read_csv(out_path)
assert len(df_check) == len(df), 'Error: numero de filas diferente'
print(f'Dataset exportado: {out_path}')
print(f'Filas: {len(df_check):,}  |  Columnas: {df_check.shape[1]}')
df_check.head()
# Out:
# Dataset exportado: ../data/processed/GoogleAds_Processed.csv
# Filas: 2,366  |  Columnas: 20
#    Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0  A1000  Data Analytics Course   104.0       4498.0  231.88   14.0
# 1  A1001  Data Analytics Course   173.0       5107.0  216.84   10.0
# 2  A1002  Data Analytics Course    90.0       4544.0  203.66   26.0
# 3  A1003  Data Analytics Course   142.0       3185.0  237.66   17.0
# 4  A1004  Data Analytics Course   156.0       3361.0  195.90   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0         0.058000       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0         0.046000       1679.0  2024-11-20  hyderabad   mobile
# 2          9.0         0.100000       1624.0  2024-11-16  hyderabad  desktop
# 3          6.0         0.042254       1225.0  2024-11-26  hyderabad   tablet
# 4          8.0         0.051282       1091.0  2024-11-22  hyderabad  desktop
#
# ...

# %% [markdown]
# ## 6. Conclusiones
#
# ### Limpieza de Datos
# - Se normalizaron `Device`, `Location` y `Campaign_Name` eliminando inconsistencias.
# - `Cost` y `Sale_Amount` se convirtieron de string con `$` a `float64`.
# - Las fechas con multiples formatos se unificaron correctamente.
# - Los valores nulos se imputaron con la **mediana**.
# - Los outliers se trataron con **Winsorizacion IQR** para conservar todos los registros.
#
# ### Ingenieria de Caracteristicas
#
# #### Features para EDA (exploración visual en este notebook)
#
# | Feature | Formula | Descripcion |
# |---|---|---|
# | `ROAS` | Sale_Amount / Cost | Retorno por dolar invertido en publicidad |
# | `CTR` | Clicks / Impressions | Relevancia del anuncio |
# | `CPC` | Cost / Clicks | Costo por clic |
# | `Day_of_Week` | dt.dayofweek | Dia de la semana del anuncio |
# | `Is_Profitable` | Profit_Margin >= tau | Variable objetivo binaria por margen para clasificacion posterior |
#
# #### Features de eficiencia que entran al modelo (creadas en `data_preprocessing.py`)
#
# Estos ratios se calculan sobre los valores monetarios **crudos**, antes de eliminar `Cost` y `Sale_Amount`, evitando leakage directo al modelo.
#
# | Feature | Formula | Descripcion |
# |---|---|---|
# | `cost_per_click` | Cost / Clicks | Costo promedio por clic recibido |
# | `cost_per_lead` | Cost / Leads | Costo promedio por lead generado |
# | `revenue_per_click` | Sale_Amount / Clicks | Ingreso promedio por clic recibido |
# | `revenue_per_lead` | Sale_Amount / Leads | Ingreso promedio por lead generado |
# | `ctr` | Clicks / Impressions | Click-through rate (eficiencia de trafico) |
# | `lead_rate` | Leads / Clicks | Tasa de conversion de clic a lead |
#
# > **Nota:** `Cost` y `Sale_Amount` en bruto **no** entran al modelo porque revelan el profit de forma casi directa (`profit = sale - cost`), lo que constituiria leakage. Los ratios capturan eficiencia relativa sin exponer los valores absolutos.
#
# Donde `Profit_Margin = (Sale_Amount - Cost) / Cost` y `tau` se selecciona automaticamente para producir la clase mas balanceada posible (candidatos: 0.10, 0.20, 0.30; fallback: percentil 70).
#
# El dataset procesado queda guardado en `data/processed/GoogleAds_Processed.csv`.
